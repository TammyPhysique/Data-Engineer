# %% [markdown]
# # Seaborn: scatterplots bouwen
# Hieronder gaan we `seaborn` gebruiken om scatterplots te maken en te kijken of we verbanden kunnen zien.

# %% [markdown]
# ## Import
# Eerst importeren we `pandas` en laden we het bronbestand.

# %%
import pandas as pd

df = pd.read_csv('pokemon_small.csv')

# %% [markdown]
# ## Hoe hoger een POKÉMONs attack, des te hoger zijn HP?
# We bouwen een eerste scatterplot waarin we kijken naar de relatie tussen `Attack` en `HP`:

# %%
import seaborn as sns

sns.scatterplot(x='Attack', y='HP', data=df)
# Out:
# <AxesSubplot:xlabel='Attack', ylabel='HP'>

# %% [markdown]
# We lijken een zwakke correlatie te zien; hogere `Attack` lijkt vaker dan niet een hogere `HP` te geven.

# %% [markdown]
# ## Hoe hoger een POKÉMONs attack, des te hoger zijn snelheid?
# Nu kijken we naar `Attack` versus `Speed`:

# %%
sns.scatterplot(x='Attack', y='Speed', data=df)
# Out:
# <AxesSubplot:xlabel='Attack', ylabel='Speed'>

# %% [markdown]
# In dit geval lijkt er geen correlatie te zijn; de verdeling is willekeurig.

# %% [markdown]
# ## Onderscheid naar Stage
# Kunnen we een verschil zien als we de waarden voor `Stage` ook meenemen?
# ### Attack versus HP
# We kijken nu of we in de data van de eerste scatterplot iets interessants zien als we de stippen kleuren a.d.h.v. hun waarde voor `Stage`.

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(10, 10))
sns.scatterplot(x='Attack', y='HP', data=df, hue='Stage', palette='Set1')
# Out:
# <AxesSubplot:xlabel='Attack', ylabel='HP'>

# %% [markdown]
# ### Attack versus Speed
# We kijken nu of we in de data van de **tweede** scatterplot iets interessants zien als we de stippen kleuren a.d.h.v. hun waarde voor `Stage`.

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x='Attack', y='Speed', data=df, hue='Stage', palette='Set1')
# Out:
# <AxesSubplot:xlabel='Attack', ylabel='Speed'>

# %% [markdown]
# ### Conclusie
# We kunnen concluderen dat `Stage` geen grote correlatie lijkt te hebben met `HP` en `Speed`; `Attack` lijkt wel vaker hoger te zijn voor Stage 2 en 3, en lager voor Stage 1.
